# %%
] activate .
# Out:
#   Activating new project at `~/.julia/dev/HJB/examples`

# %%
using Revise, BenchmarkTools

# %%
] st
# Out:
# Status `~/.julia/dev/HJB/examples/Project.toml` (empty project)

# %%
Threads.nthreads()
# Out:
# 16

# %%
using LinearAlgebra, StaticArrays, Plots, ForwardDiff

# %%
include("../src/HJB.jl")
# Out:
# WARNING: replacing module HJB.
# Main.HJB

# %%
# create the grid
x1s = range(-1.0, 2.0, length=256)
x2s = range(-1.0, 2.0, length=256)

grid = HJB.Grid((x1s, x2s))
# Out:
# Main.HJB.Grid{2, Float64}((-1.0, -1.0), (0.011764705882352941, 0.011764705882352941), (256, 256))

# %%
function plot_grid!(data, grid::HJB.Grid{2, F}) where {F}
    # for now only supports plotting 2 dimensional problems

    x1s = HJB.get_axes(grid, 1)
    x2s = HJB.get_axes(grid, 2)

    heatmap!(x1s, x2s, data')

end
# Out:
# plot_grid! (generic function with 2 methods)

# %%
# define the dynamics
function f(t, x, u)
    return @SVector [x[2], u[1]]
end
# Out:
# f (generic function with 1 method)

# %%
# define the Hamiltonian
function H(t, x, V, DxV, params)
    # u1 = @SVector [1.0]
    # u2 = @SVector [-1.0]

    # H1 = DxV' * f(t, x, u1)
    # H2 = DxV' * f(t, x, u2)

    # γ = 0

    # return min(0, max(H1, H2) + γ*V)

    u2 = @SVector [-1.0]
    H2 = DxV' * f(t, x, u2)
    γ = 0.5
    
    return min(0, H2 + γ*V)
end
# Out:
# H (generic function with 1 method)

# %%
# define the constraint function
function l(x)
    return 1.5 - x[1]
    
    # maxX = 1.5 - x[1]
    # maxV = 1.5 - x[2]
    
    # return min(maxX, maxV)

    # minV = x[2] + 0.5

    # if x[2] > 1.5
    #     return 1.5 - x[2]
    # else
    #     return maxX
    # end
    
    # return min(maxX, maxV)
    # # return min(maxV, minV)
    
    
end
# Out:
# l (generic function with 1 method)

# %%
function max_DpH(t, x)

    # should return max( abs( f(t, x, u2))  )
    # f(t, x, u) = @SVector [x[2], u[1]]
    # f(t, x, u) = [x[2], 0] + [0, u[1]]
    # ie. fx(t, x) = [x[2], 0]
    #     gx(t, x) = [0, 1]
    # so the dissipation coefficients by (25) of ToolboxLS are
    # \alpha_j(x) = | fx(t, x)_j |  + sum_{i=1}^{m} |gx_{ji}(t, x)| U_i
    # where m is the number of control inputs

    α = @SVector [abs(x[2]), 1.0]
    # α = @SVector [2, 1.]
    # α = @SVector [ 20, 10.] 
    # α = @SVector [ 0.2, 0.1 ] 
    
    return α
end
# Out:
# max_DpH (generic function with 1 method)

# %%
# construct the HJB problem
tspan = (0.0, 2.0)
prob = HJB.HJBProblem(H, l, tspan)
# Out:
# Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}(H, l, (0.0, 2.0), nothing)

# %%
VF = HJB.allocate_grid(Float64, grid, l)
dV = similar(VF);

# %%
timeMethod = HJB.LaxFriedrichs(max_DpH)
# Out:
# Main.HJB.LaxFriedrichs(max_DpH)

# %%
RHS! = HJB.get_ODE_RHS(prob, grid, timeMethod,HJB.WENO())
# Out:
# (::Main.HJB.var"#RHS!#30"{Main.HJB.Grid{2, Float64}, Main.HJB.WENO, Main.HJB.var"#numH#36"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, typeof(max_DpH)}}) (generic function with 1 method)

# %%
HJB.DiffEq.RK4
# Out:
# OrdinaryDiffEq.RK4

# %%
# solve the ODE
# gradMethod = HJB.Simple()
gradMethod = HJB.WENO()
timeMethod = HJB.Direct()
# timeMethod = HJB.LaxFriedrichs(max_DpH)
# alg=HJB.DiffEq.Euler()
# alg = HJB.DiffEq.RK4()
alg=HJB.DiffEq.Vern7()
@time sol = HJB.solve_MOL(prob, grid; gradMethod=gradMethod, timeMethod=timeMethod,  alg=alg, dt=0.1e-3, dtmax=1e-3, reltol=1e-8, abstol=1e-8)

# %%
sol.sol.alg

# %%
sol.sol.t

# %%
# @time sol = HJB.solve_MOL(prob, grid; gradMethod=HJB.Simple(), timeMethod=timeMethod, dtmax=1e-4, reltol=1e-6, abstol=1e-6)

# %%
sol.sol.alg

# %%
sol.sol

# %%
ind = 1 # length(sol.sol.t)

p1 = plot()
plot_grid!(sol.sol.u[ind], grid)
title!("t = $(sol.sol.t[ind])")

p2 = plot()
plot_grid!(sol.sol.u[ind] .>= 0.0, grid)
title!("t = $(sol.sol.t[ind])")

plot!(p1, p2)

# %%
ind = 150 # length(sol.sol.t)

p1 = plot()
plot_grid!(sol.sol.u[ind], grid)
title!("t = $(sol.sol.t[ind])")

p2 = plot()
plot_grid!(sol.sol.u[ind] .>= 0.0, grid)
title!("t = $(sol.sol.t[ind])")

plot!(p1, p2)

# %%
ind = round(Int, (1/10) * length(sol.sol.t))

p1 = plot()
plot_grid!(sol.sol.u[ind], grid)
title!("t = $(sol.sol.t[ind])")

p2 = plot()
plot_grid!(sol.sol.u[ind] .>= 0.0, grid)
title!("t = $(sol.sol.t[ind])")

plot!(p1, p2)

# %%
ind =  length(sol.sol.t)

p1 = plot()
plot_grid!(sol.sol.u[ind], grid)
title!("t = $(sol.sol.t[ind])")

p2 = plot()
plot_grid!(sol.sol.u[ind] .>= 0.0, grid)
title!("t = $(sol.sol.t[ind])")

plot!(p1, p2)

# %%
maximum(-diff(sol.sol.t))

# %%
minimum(-diff(sol.sol.t))

# %%
plot(-diff(sol.sol.t))

# %%
# # solve the ODE
# @time sol = HJB.solve_MOL(prob, grid; gradMethod=HJB.Simple(), timeMethod=HJB.Direct(), alg=HJB.DiffEq.Euler(), dt=1e-3, reltol=1e-8, abstol=1e-8)
# Out:
# InterruptException:
#
# Stacktrace:
#   [1] copy
#     @ RecursiveArrayTools ./array.jl:409 [inlined]
#   [2] recursivecopy
#     @ RecursiveArrayTools ~/.julia/packages/RecursiveArrayTools/X30HP/src/utils.jl:17 [inlined]
#   [3] map!
#     @ RecursiveArrayTools ./abstractarray.jl:3268 [inlined]
#   [4] recursivecopy(a::Vector{Matrix{Float64}})
#     @ RecursiveArrayTools ~/.julia/packages/RecursiveArrayTools/X30HP/src/utils.jl:23
#   [5] copyat_or_push!(a::Vector{Vector{Matrix{Float64}}}, i::Int64, x::Vector{Matrix{Float64}}, perform_copy::Bool)
#     @ RecursiveArrayTools ~/.julia/packages/RecursiveArrayTools/X30HP/src/utils.jl:198
#   [6] copyat_or_push!(a::AbstractVector{T}, i::Int64, x::Any, perform_copy::Any) where T
#     @ RecursiveArrayTools ~/.julia/packages/RecursiveArrayTools/X30HP/src/utils.jl:184 [inlined]
#   [7] _savevalues!(integrator::OrdinaryDiffEq.ODEIntegrator{OrdinaryDiffEq.Euler, true, Matrix{Float64}, Nothing, Float64, Nothing, Float64, Float64, Float64, Float64, Vector{Matrix{Float64}}, SciMLBase.ODESolution{Float64, 3, Vector{Matrix{Float64}}, Nothing, Nothing, Vector{Float64}, Vector{Vector{Matrix{Float64}}}, SciMLBase.ODEProblem{Matrix{Float64}, Tuple{Float64, Float64}, true, Nothing, SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.Simple}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, @Kwargs{}, SciMLBase.StandardODEProblem}, OrdinaryDiffEq.Euler, OrdinaryDiffEq.InterpolationData{SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.Simple}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, Vector{Matrix{Float64}}, Vector{Float64}, Vector{Vector{Matrix{Float64}}}, OrdinaryDiffEq.EulerCache{Matrix{Float64}, Matrix{Float64}}}, DiffEqBase.Stats, Nothing}, SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.Simple}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, OrdinaryDiffEq.EulerCache{Matrix{Float64}, Matrix{Float64}}, OrdinaryDiffEq.DEOptions{Float64, Float64, Float64, Float64, OrdinaryDiffEq.PIController{Int64}, typeof(DiffEqBase.ODE_DEFAULT_NORM), typeof(opnorm), Nothing, SciMLBase.CallbackSet{Tuple{}, Tuple{}}, typeof(DiffEqBase.ODE_DEFAULT_ISOUTOFDOMAIN), typeof(DiffEqBase.ODE_DEFAULT_PROG_MESSAGE), typeof(DiffEqBase.ODE_DEFAULT_UNSTABLE_CHECK), DataStructures.BinaryHeap{Float64, DataStructures.FasterForward}, DataStructures.BinaryHeap{Float64, DataStructures.FasterForward}, Nothing, Nothing, Int64, Tuple{}, Tuple{}, Tuple{}}, Matrix{Float64}, Float64, Nothing, OrdinaryDiffEq.DefaultInit}, force_save::Bool, reduce_size::Bool)
#     @ OrdinaryDiffEq ~/.julia/packages/OrdinaryDiffEq/yppG9/src/integrators/integrator_utils.jl:124
#   [8] savevalues! (repeats 2 times)
#     @ OrdinaryDiffEq ~/.julia/packages/OrdinaryDiffEq/yppG9/src/integrators/integrator_utils.jl:58 [inlined]
#   [9] handle_callbacks!
#     @ OrdinaryDiffEq ~/.julia/packages/OrdinaryDiffEq/yppG9/src/integrators/integrator_utils.jl:343 [inlined]
#  [10] _loopfooter!(integrator::OrdinaryDiffEq.ODEIntegrator{OrdinaryDiffEq.Euler, true, Matrix{Float64}, Nothing, Float64, Nothing, Float64, Float64, Float64, Float64, Vector{Matrix{Float64}}, SciMLBase.ODESolution{Float64, 3, Vector{Matrix{Float64}}, Nothing, Nothing, Vector{Float64}, Vector{Vector{Matrix{Float64}}}, SciMLBase.ODEProblem{Matrix{Float64}, Tuple{Float64, Float64}, true, Nothing, SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.Simple}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, @Kwargs{}, SciMLBase.StandardODEProblem}, OrdinaryDiffEq.Euler, OrdinaryDiffEq.InterpolationData{SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.Simple}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, Vector{Matrix{Float64}}, Vector{Float64}, Vector{Vector{Matrix{Float64}}}, OrdinaryDiffEq.EulerCache{Matrix{Float64}, Matrix{Float64}}}, DiffEqBase.Stats, Nothing}, SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.Simple}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, OrdinaryDiffEq.EulerCache{Matrix{Float64}, Matrix{Float64}}, OrdinaryDiffEq.DEOptions{Float64, Float64, Float64, Float64, OrdinaryDiffEq.PIController{Int64}, typeof(DiffEqBase.ODE_DEFAULT_NORM), typeof(opnorm), Nothing, SciMLBase.CallbackSet{Tuple{}, Tuple{}}, typeof(DiffEqBase.ODE_DEFAULT_ISOUTOFDOMAIN), typeof(DiffEqBase.ODE_DEFAULT_PROG_MESSAGE), typeof(DiffEqBase.ODE_DEFAULT_UNSTABLE_CHECK), DataStructures.BinaryHeap{Float64, DataStructures.FasterForward}, DataStructures.BinaryHeap{Float64, DataStructures.FasterForward}, Nothing, Nothing, Int64, Tuple{}, Tuple{}, Tuple{}}, Matrix{Float64}, Float64, Nothing, OrdinaryDiffEq.DefaultInit})
#     @ OrdinaryDiffEq ~/.julia/packages/OrdinaryDiffEq/yppG9/src/integrators/integrator_utils.jl:267
#  [11] loopfooter!
#     @ OrdinaryDiffEq ~/.julia/packages/OrdinaryDiffEq/yppG9/src/integrators/integrator_utils.jl:199 [inlined]
#  [12] solve!(integrator::OrdinaryDiffEq.ODEIntegrator{OrdinaryDiffEq.Euler, true, Matrix{Float64}, Nothing, Float64, Nothing, Float64, Float64, Float64, Float64, Vector{Matrix{Float64}}, SciMLBase.ODESolution{Float64, 3, Vector{Matrix{Float64}}, Nothing, Nothing, Vector{Float64}, Vector{Vector{Matrix{Float64}}}, SciMLBase.ODEProblem{Matrix{Float64}, Tuple{Float64, Float64}, true, Nothing, SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.Simple}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, @Kwargs{}, SciMLBase.StandardODEProblem}, OrdinaryDiffEq.Euler, OrdinaryDiffEq.InterpolationData{SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.Simple}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, Vector{Matrix{Float64}}, Vector{Float64}, Vector{Vector{Matrix{Float64}}}, OrdinaryDiffEq.EulerCache{Matrix{Float64}, Matrix{Float64}}}, DiffEqBase.Stats, Nothing}, SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.Simple}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, OrdinaryDiffEq.EulerCache{Matrix{Float64}, Matrix{Float64}}, OrdinaryDiffEq.DEOptions{Float64, Float64, Float64, Float64, OrdinaryDiffEq.PIController{Int64}, typeof(DiffEqBase.ODE_DEFAULT_NORM), typeof(opnorm), Nothing, SciMLBase.CallbackSet{Tuple{}, Tuple{}}, typeof(DiffEqBase.ODE_DEFAULT_ISOUTOFDOMAIN), typeof(DiffEqBase.ODE_DEFAULT_PROG_MESSAGE), typeof(DiffEqBase.ODE_DEFAULT_UNSTABLE_CHECK), DataStructures.BinaryHeap{Float64, DataStructures.FasterForward}, DataStructures.BinaryHeap{Float64, DataStructures.FasterForward}, Nothing, Nothing, Int64, Tuple{}, Tuple{}, Tuple{}}, Matrix{Float64}, Float64, Nothing, OrdinaryDiffEq.DefaultInit})
#     @ OrdinaryDiffEq ~/.julia/packages/OrdinaryDiffEq/yppG9/src/solve.jl:529
#  [13] __solve(prob::Union{SciMLBase.AbstractDAEProblem, SciMLBase.AbstractODEProblem}, alg::Union{OrdinaryDiffEq.OrdinaryDiffEqAlgorithm, OrdinaryDiffEq.DAEAlgorithm}, args::Vararg{Any}; kwargs...)
#     @ OrdinaryDiffEq ~/.julia/packages/OrdinaryDiffEq/yppG9/src/solve.jl:6 [inlined]
#  [14] __solve
#     @ DiffEqBase ~/.julia/packages/OrdinaryDiffEq/yppG9/src/solve.jl:1 [inlined]
#  [15] solve_call(_prob::SciMLBase.ODEProblem{Matrix{Float64}, Tuple{Float64, Float64}, true, Nothing, SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.Simple}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, @Kwargs{}, SciMLBase.StandardODEProblem}, args::OrdinaryDiffEq.Euler; merge_callbacks::Bool, kwargshandle::Nothing, kwargs::@Kwargs{alg::OrdinaryDiffEq.Euler, dt::Float64, reltol::Float64, abstol::Float64})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/xSmHR/src/solve.jl:571
#  [16] solve_call
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/xSmHR/src/solve.jl:537 [inlined]
#  [17] solve_up(::SciMLBase.ODEProblem{Matrix{Float64}, Tuple{Float64, Float64}, true, Nothing, SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.Simple}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, @Kwargs{}, SciMLBase.StandardODEProblem}, ::Nothing, ::Matrix{Float64}, ::Nothing; kwargs::@Kwargs{alg::OrdinaryDiffEq.Euler, dt::Float64, reltol::Float64, abstol::Float64})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/xSmHR/src/solve.jl:1014
#  [18] solve_up
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/xSmHR/src/solve.jl:1006 [inlined]
#  [19] solve(::SciMLBase.ODEProblem{Matrix{Float64}, Tuple{Float64, Float64}, true, Nothing, SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.Simple}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, @Kwargs{}, SciMLBase.StandardODEProblem}; sensealg::Nothing, u0::Nothing, p::Nothing, wrap::Val{true}, kwargs::@Kwargs{alg::OrdinaryDiffEq.Euler, dt::Float64, reltol::Float64, abstol::Float64})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/xSmHR/src/solve.jl:943
#  [20] solve_MOL(prob::Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, grid::Main.HJB.Grid{2, Float64}; timeMethod::Main.HJB.Direct, gradMethod::Main.HJB.Simple, kwargs::@Kwargs{alg::OrdinaryDiffEq.Euler, dt::Float64, reltol::Float64, abstol::Float64})
#     @ Main.HJB ~/.julia/dev/HJB/src/hjb_problem.jl:128
#  [21] macro expansion
#     @ ./timing.jl:279 [inlined]
#  [22] top-level scope
#     @ ./In[144]:2

# %%
ind = round(Int, (10/10) * length(sol.sol.t))

p1 = plot()
plot_grid!(sol.sol.u[ind], grid)
title!("t = $(sol.sol.t[ind])")

p2 = plot()
plot_grid!(sol.sol.u[ind] .>= 0.0, grid)
title!("t = $(sol.sol.t[ind])")

plot!(p1, p2)

# %%
# solve the ODE
@time sol = HJB.solve_MOL(prob, grid; gradMethod=HJB.WENO(), timeMethod=HJB.Direct(), alg=HJB.DiffEq.Euler(), dt=1e-4, reltol=1e-8, abstol=1e-8)
# Out:
# InterruptException:
#
# Stacktrace:
#   [1] copy
#     @ RecursiveArrayTools ./array.jl:409 [inlined]
#   [2] recursivecopy
#     @ RecursiveArrayTools ~/.julia/packages/RecursiveArrayTools/X30HP/src/utils.jl:17 [inlined]
#   [3] map!
#     @ RecursiveArrayTools ./abstractarray.jl:3268 [inlined]
#   [4] recursivecopy(a::Vector{Matrix{Float64}})
#     @ RecursiveArrayTools ~/.julia/packages/RecursiveArrayTools/X30HP/src/utils.jl:23
#   [5] copyat_or_push!(a::Vector{Vector{Matrix{Float64}}}, i::Int64, x::Vector{Matrix{Float64}}, perform_copy::Bool)
#     @ RecursiveArrayTools ~/.julia/packages/RecursiveArrayTools/X30HP/src/utils.jl:198
#   [6] copyat_or_push!(a::AbstractVector{T}, i::Int64, x::Any, perform_copy::Any) where T
#     @ RecursiveArrayTools ~/.julia/packages/RecursiveArrayTools/X30HP/src/utils.jl:184 [inlined]
#   [7] _savevalues!(integrator::OrdinaryDiffEq.ODEIntegrator{OrdinaryDiffEq.Euler, true, Matrix{Float64}, Nothing, Float64, Nothing, Float64, Float64, Float64, Float64, Vector{Matrix{Float64}}, SciMLBase.ODESolution{Float64, 3, Vector{Matrix{Float64}}, Nothing, Nothing, Vector{Float64}, Vector{Vector{Matrix{Float64}}}, SciMLBase.ODEProblem{Matrix{Float64}, Tuple{Float64, Float64}, true, Nothing, SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.WENO}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, @Kwargs{}, SciMLBase.StandardODEProblem}, OrdinaryDiffEq.Euler, OrdinaryDiffEq.InterpolationData{SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.WENO}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, Vector{Matrix{Float64}}, Vector{Float64}, Vector{Vector{Matrix{Float64}}}, OrdinaryDiffEq.EulerCache{Matrix{Float64}, Matrix{Float64}}}, DiffEqBase.Stats, Nothing}, SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.WENO}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, OrdinaryDiffEq.EulerCache{Matrix{Float64}, Matrix{Float64}}, OrdinaryDiffEq.DEOptions{Float64, Float64, Float64, Float64, OrdinaryDiffEq.PIController{Int64}, typeof(DiffEqBase.ODE_DEFAULT_NORM), typeof(opnorm), Nothing, SciMLBase.CallbackSet{Tuple{}, Tuple{}}, typeof(DiffEqBase.ODE_DEFAULT_ISOUTOFDOMAIN), typeof(DiffEqBase.ODE_DEFAULT_PROG_MESSAGE), typeof(DiffEqBase.ODE_DEFAULT_UNSTABLE_CHECK), DataStructures.BinaryHeap{Float64, DataStructures.FasterForward}, DataStructures.BinaryHeap{Float64, DataStructures.FasterForward}, Nothing, Nothing, Int64, Tuple{}, Tuple{}, Tuple{}}, Matrix{Float64}, Float64, Nothing, OrdinaryDiffEq.DefaultInit}, force_save::Bool, reduce_size::Bool)
#     @ OrdinaryDiffEq ~/.julia/packages/OrdinaryDiffEq/yppG9/src/integrators/integrator_utils.jl:124
#   [8] savevalues! (repeats 2 times)
#     @ OrdinaryDiffEq ~/.julia/packages/OrdinaryDiffEq/yppG9/src/integrators/integrator_utils.jl:58 [inlined]
#   [9] handle_callbacks!
#     @ OrdinaryDiffEq ~/.julia/packages/OrdinaryDiffEq/yppG9/src/integrators/integrator_utils.jl:343 [inlined]
#  [10] _loopfooter!(integrator::OrdinaryDiffEq.ODEIntegrator{OrdinaryDiffEq.Euler, true, Matrix{Float64}, Nothing, Float64, Nothing, Float64, Float64, Float64, Float64, Vector{Matrix{Float64}}, SciMLBase.ODESolution{Float64, 3, Vector{Matrix{Float64}}, Nothing, Nothing, Vector{Float64}, Vector{Vector{Matrix{Float64}}}, SciMLBase.ODEProblem{Matrix{Float64}, Tuple{Float64, Float64}, true, Nothing, SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.WENO}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, @Kwargs{}, SciMLBase.StandardODEProblem}, OrdinaryDiffEq.Euler, OrdinaryDiffEq.InterpolationData{SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.WENO}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, Vector{Matrix{Float64}}, Vector{Float64}, Vector{Vector{Matrix{Float64}}}, OrdinaryDiffEq.EulerCache{Matrix{Float64}, Matrix{Float64}}}, DiffEqBase.Stats, Nothing}, SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.WENO}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, OrdinaryDiffEq.EulerCache{Matrix{Float64}, Matrix{Float64}}, OrdinaryDiffEq.DEOptions{Float64, Float64, Float64, Float64, OrdinaryDiffEq.PIController{Int64}, typeof(DiffEqBase.ODE_DEFAULT_NORM), typeof(opnorm), Nothing, SciMLBase.CallbackSet{Tuple{}, Tuple{}}, typeof(DiffEqBase.ODE_DEFAULT_ISOUTOFDOMAIN), typeof(DiffEqBase.ODE_DEFAULT_PROG_MESSAGE), typeof(DiffEqBase.ODE_DEFAULT_UNSTABLE_CHECK), DataStructures.BinaryHeap{Float64, DataStructures.FasterForward}, DataStructures.BinaryHeap{Float64, DataStructures.FasterForward}, Nothing, Nothing, Int64, Tuple{}, Tuple{}, Tuple{}}, Matrix{Float64}, Float64, Nothing, OrdinaryDiffEq.DefaultInit})
#     @ OrdinaryDiffEq ~/.julia/packages/OrdinaryDiffEq/yppG9/src/integrators/integrator_utils.jl:267
#  [11] loopfooter!
#     @ OrdinaryDiffEq ~/.julia/packages/OrdinaryDiffEq/yppG9/src/integrators/integrator_utils.jl:199 [inlined]
#  [12] solve!(integrator::OrdinaryDiffEq.ODEIntegrator{OrdinaryDiffEq.Euler, true, Matrix{Float64}, Nothing, Float64, Nothing, Float64, Float64, Float64, Float64, Vector{Matrix{Float64}}, SciMLBase.ODESolution{Float64, 3, Vector{Matrix{Float64}}, Nothing, Nothing, Vector{Float64}, Vector{Vector{Matrix{Float64}}}, SciMLBase.ODEProblem{Matrix{Float64}, Tuple{Float64, Float64}, true, Nothing, SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.WENO}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, @Kwargs{}, SciMLBase.StandardODEProblem}, OrdinaryDiffEq.Euler, OrdinaryDiffEq.InterpolationData{SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.WENO}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, Vector{Matrix{Float64}}, Vector{Float64}, Vector{Vector{Matrix{Float64}}}, OrdinaryDiffEq.EulerCache{Matrix{Float64}, Matrix{Float64}}}, DiffEqBase.Stats, Nothing}, SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.WENO}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, OrdinaryDiffEq.EulerCache{Matrix{Float64}, Matrix{Float64}}, OrdinaryDiffEq.DEOptions{Float64, Float64, Float64, Float64, OrdinaryDiffEq.PIController{Int64}, typeof(DiffEqBase.ODE_DEFAULT_NORM), typeof(opnorm), Nothing, SciMLBase.CallbackSet{Tuple{}, Tuple{}}, typeof(DiffEqBase.ODE_DEFAULT_ISOUTOFDOMAIN), typeof(DiffEqBase.ODE_DEFAULT_PROG_MESSAGE), typeof(DiffEqBase.ODE_DEFAULT_UNSTABLE_CHECK), DataStructures.BinaryHeap{Float64, DataStructures.FasterForward}, DataStructures.BinaryHeap{Float64, DataStructures.FasterForward}, Nothing, Nothing, Int64, Tuple{}, Tuple{}, Tuple{}}, Matrix{Float64}, Float64, Nothing, OrdinaryDiffEq.DefaultInit})
#     @ OrdinaryDiffEq ~/.julia/packages/OrdinaryDiffEq/yppG9/src/solve.jl:529
#  [13] __solve(prob::Union{SciMLBase.AbstractDAEProblem, SciMLBase.AbstractODEProblem}, alg::Union{OrdinaryDiffEq.OrdinaryDiffEqAlgorithm, OrdinaryDiffEq.DAEAlgorithm}, args::Vararg{Any}; kwargs...)
#     @ OrdinaryDiffEq ~/.julia/packages/OrdinaryDiffEq/yppG9/src/solve.jl:6 [inlined]
#  [14] __solve
#     @ DiffEqBase ~/.julia/packages/OrdinaryDiffEq/yppG9/src/solve.jl:1 [inlined]
#  [15] solve_call(_prob::SciMLBase.ODEProblem{Matrix{Float64}, Tuple{Float64, Float64}, true, Nothing, SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.WENO}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, @Kwargs{}, SciMLBase.StandardODEProblem}, args::OrdinaryDiffEq.Euler; merge_callbacks::Bool, kwargshandle::Nothing, kwargs::@Kwargs{alg::OrdinaryDiffEq.Euler, dt::Float64, reltol::Float64, abstol::Float64})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/xSmHR/src/solve.jl:571
#  [16] solve_call
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/xSmHR/src/solve.jl:537 [inlined]
#  [17] solve_up(::SciMLBase.ODEProblem{Matrix{Float64}, Tuple{Float64, Float64}, true, Nothing, SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.WENO}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, @Kwargs{}, SciMLBase.StandardODEProblem}, ::Nothing, ::Matrix{Float64}, ::Nothing; kwargs::@Kwargs{alg::OrdinaryDiffEq.Euler, dt::Float64, reltol::Float64, abstol::Float64})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/xSmHR/src/solve.jl:1014
#  [18] solve_up
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/xSmHR/src/solve.jl:1006 [inlined]
#  [19] solve(::SciMLBase.ODEProblem{Matrix{Float64}, Tuple{Float64, Float64}, true, Nothing, SciMLBase.ODEFunction{true, SciMLBase.FullSpecialize, Main.HJB.var"#RHS!#26"{Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, Main.HJB.Grid{2, Float64}, Main.HJB.WENO}, UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, @Kwargs{}, SciMLBase.StandardODEProblem}; sensealg::Nothing, u0::Nothing, p::Nothing, wrap::Val{true}, kwargs::@Kwargs{alg::OrdinaryDiffEq.Euler, dt::Float64, reltol::Float64, abstol::Float64})
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/xSmHR/src/solve.jl:943
#  [20] solve_MOL(prob::Main.HJB.HJBProblem{Float64, typeof(H), typeof(l), Nothing}, grid::Main.HJB.Grid{2, Float64}; timeMethod::Main.HJB.Direct, gradMethod::Main.HJB.WENO, kwargs::@Kwargs{alg::OrdinaryDiffEq.Euler, dt::Float64, reltol::Float64, abstol::Float64})
#     @ Main.HJB ~/.julia/dev/HJB/src/hjb_problem.jl:128
#  [21] macro expansion
#     @ ./timing.jl:279 [inlined]
#  [22] top-level scope
#     @ ./In[142]:2

# %%
ind = round(Int, (10/10) * length(sol.sol.t))

p1 = plot()
plot_grid!(sol.sol.u[ind], grid)
title!("t = $(sol.sol.t[ind])")

p2 = plot()
plot_grid!(sol.sol.u[ind] .>= 0.0, grid)
title!("t = $(sol.sol.t[ind])")

plot!(p1, p2)
